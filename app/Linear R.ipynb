# %%
import pandas as pd
housing_data = pd.read_csv('housing_small.csv')
housing_data
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -121.84     38.02                  46           66              22
# 1     -121.94     38.38                  25          182              48
# 2     -117.37     33.98                  27         1342             547
# 3     -119.82     36.76                  46         2194             563
# 4     -121.32     38.00                  21         1795             482
# 5     -121.79     38.00                  36         1141             234
# 6     -121.37     38.61                  39          823             146
# 7     -119.96     38.84                  17         2722             512
# 8     -117.20     34.52                  12         4476             761
# 9     -122.03     38.25                  13         3334             541
# 10    -121.84     37.99                  15         2380             385
# 11    -121.34     38.03                  12         2707             433
# 12    -117.31     34.35                   9         2404             390
# 13    -122.01     38.37                  16         3996             550
# 14    -118.21     34.64                  16         2573             427
# 15    -122.02     38.38                  16          808             137
# 16    -121.22     38.78                   8         3418             514
# 17    -122.03     38.30                   5         1569             199
# 18    -117.68     34.14                   4         4791             695
# 19    -117.57     33.93                   3         1240             151
# 20    -117.71     34.15                  17        17715            2370
# 21    -117.66     34.12                  22         2272             278
# 22    -121.99     37.92                  14         1780             224
# 23    -119.84     36.85                   8         3791             487
# 24    -121.88     37.64                  20         1309             184
# 25    -121.96     37.85                  10         3209             379
# 26    -121.97     37.87                   4         1029             126
# 27    -118.06     34.15                  37         1980             226
#
#     population  households  median_income  median_house_value ocean_proximity
# 0           37          21         0.5360               87500          INLAND
# 1           71          52         1.0208               78600          INLAND
# 2          844         484         1.1194               95800          INLAND
# 3          924         542         1.4028               68500          INLAND
# 4         1114         472         2.0091              101500          INLAND
# 5          562         213         2.5893              108500          INLAND
# 6          329         144         3.0833              114100          INLAND
# 7          828         289         3.5714              109700          INLAND
# 8         2255         735         3.9250              118500          INLAND
# 9         1923         538         4.0905              134800          INLAND
# 10        1292         388         4.6029              142600          INLAND
# 11        1200         380         4.9861              133500          INLAND
# 12        1074         359         5.0198              151900          INLAND
# 13        1673         539         5.7780              175700          INLAND
# 14        1273         426         5.9508              181100          INLAND
# 15         371         145         6.0767              216400          INLAND
# 16        1312         409         6.3914              218000          INLAND
# 17         713         209         6.6779              223900          INLAND
# 18        1871         659         6.9532              277000          INLAND
# 19         519         146         7.5408              271900          INLAND
# 20        7665        2312         7.9068              349100          INLAND
# 21         933         305         8.8204              390500          INLAND
# 22         764         226         9.0243              427700          INLAND
# 23        1424         475        10.5144              345900          INLAND
# 24         514         172        10.9506              475800          INLAND
# 25        1199         392        12.2478              500001          INLAND
# 26         416         122        13.4883              500001          INLAND
# 27         697         226        15.0001              500001          INLAND

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           28 non-null     float64
#  1   latitude            28 non-null     float64
#  2   housing_median_age  28 non-null     int64
#  3   total_rooms         28 non-null     int64
#  4   total_bedrooms      28 non-null     int64
#  5   population          28 non-null     int64
#  6   households          28 non-null     int64
#  7   median_income       28 non-null     float64
#  8   median_house_value  28 non-null     int64
#  9   ocean_proximity     28 non-null     object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 2.3+ KB

# %%
housing_data.describe()
# Out:
#         longitude   latitude  housing_median_age   total_rooms  \
# count   28.000000  28.000000           28.000000     28.000000
# mean  -120.247857  36.815000           18.500000   2751.642857
# std      1.939155   1.876065           12.342339   3177.302539
# min   -122.030000  33.930000            3.000000     66.000000
# 25%   -121.945000  34.477500            9.750000   1291.750000
# 50%   -121.330000  37.895000           16.000000   2233.000000
# 75%   -117.972500  38.262500           22.750000   3240.250000
# max   -117.200000  38.840000           46.000000  17715.000000
#
#        total_bedrooms   population   households  median_income  \
# count       28.000000    28.000000    28.000000      28.000000
# mean       428.964286  1207.035714   406.428571       6.117068
# std        427.569832  1378.758929   415.254088       3.843060
# min         22.000000    37.000000    21.000000       0.536000
# 25%        195.250000   551.250000   199.750000       3.449375
# 50%        387.500000   928.500000   369.500000       5.864400
# 75%        520.750000  1297.000000   477.250000       8.135200
# max       2370.000000  7665.000000  2312.000000      15.000100
#
#        median_house_value
# count           28.000000
# mean        232089.392857
# std         145573.714845
# min          68500.000000
# 25%         113000.000000
# 50%         178400.000000
# 75%         346700.000000
# max         500001.000000

# %%
housing_data.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -121.84     38.02                  46           66              22
# 1    -121.94     38.38                  25          182              48
#
#    population  households  median_income  median_house_value ocean_proximity
# 0          37          21         0.5360               87500          INLAND
# 1          71          52         1.0208               78600          INLAND

# %%
housing_data.tail()
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 23    -119.84     36.85                   8         3791             487
# 24    -121.88     37.64                  20         1309             184
# 25    -121.96     37.85                  10         3209             379
# 26    -121.97     37.87                   4         1029             126
# 27    -118.06     34.15                  37         1980             226
#
#     population  households  median_income  median_house_value ocean_proximity
# 23        1424         475        10.5144              345900          INLAND
# 24         514         172        10.9506              475800          INLAND
# 25        1199         392        12.2478              500001          INLAND
# 26         416         122        13.4883              500001          INLAND
# 27         697         226        15.0001              500001          INLAND

# %%
housing_data.shape
# Out:
# (28, 10)

# %%
X=housing_data['median_income']
X
# Out:
# 0      0.5360
# 1      1.0208
# 2      1.1194
# 3      1.4028
# 4      2.0091
# 5      2.5893
# 6      3.0833
# 7      3.5714
# 8      3.9250
# 9      4.0905
# 10     4.6029
# 11     4.9861
# 12     5.0198
# 13     5.7780
# 14     5.9508
# 15     6.0767
# 16     6.3914
# 17     6.6779
# 18     6.9532
# 19     7.5408
# 20     7.9068
# 21     8.8204
# 22     9.0243
# 23    10.5144
# 24    10.9506
# 25    12.2478
# 26    13.4883
# 27    15.0001
# Name: median_income, dtype: float64

# %%
y = housing_data['median_house_value']
y
# Out:
# 0      87500
# 1      78600
# 2      95800
# 3      68500
# 4     101500
# 5     108500
# 6     114100
# 7     109700
# 8     118500
# 9     134800
# 10    142600
# 11    133500
# 12    151900
# 13    175700
# 14    181100
# 15    216400
# 16    218000
# 17    223900
# 18    277000
# 19    271900
# 20    349100
# 21    390500
# 22    427700
# 23    345900
# 24    475800
# 25    500001
# 26    500001
# 27    500001
# Name: median_house_value, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
housing_data.plot.scatter('median_income','median_house_value')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X,y,test_size=0.2)
from sklearn.linear_model import LinearRegression

# %%
LR=LinearRegression()
LR.fit(x_train.values.reshape(-1,1),y_train.values)
predictions=LR.predict(x_test.values.reshape(-1,1))
predictions
# Out:
# array([ 41354.34533455, 154429.90878581, 222955.97670397, 500607.55813339,
#         23496.23764938, 454912.4620454 ])
